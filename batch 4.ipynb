# %%
from pathlib import Path

print(Path.cwd())

print("\nFiles in current directory:")
for file in Path(".").iterdir():
    print(file)

print("\nFiles inside data:")
for file in Path("data").glob("*"):
    print(file)
# Out:
# C:\Users\DELL\PycharmProjects\xnews-semantic-experiment
#
# Files in current directory:
# .git
# .idea
# .venv
# batch 4.ipynb
# data
# main.py
# main2.ipynb
# main2.py
# README.md
# requirements.txt
#
# Files inside data:
# data\xnews_batch1_pairs_1-100.csv
# data\xnews_batch2_pairs_101-200 .csv
# data\xnews_batch3_pairs_201-300.csv
# data\xnews_batch4_pairs_301-400.csv

# %%
# Out:
# Wrote 100 pairs to C:\Users\DELL\Downloads\xnews_batch8_pairs_801-900.csv
# SAME_EVENT: 50 DIFFERENT_EVENT: 50
# Categories: {'Technology': 10, 'Politics': 10, 'Business': 10, 'Sports': 10, 'Science': 10, 'World': 10, 'Health': 10, 'Environment': 10, 'Crime': 10, 'Entertainment': 10}
# Difficulty: {'easy': 20, 'medium': 40, 'hard': 30, 'very_hard': 10}
# Duplicate pairs within batch8: 0
# First: P0801 Last: P0900 Count: 100
